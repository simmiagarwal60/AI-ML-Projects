# %% [markdown]
# <a href="https://colab.research.google.com/github/simmiagarwal60/AI-ML-Projects/blob/main/PCADimensions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
X, y = make_blobs(n_samples=500, n_features=5, centers=3, cluster_std=1.5, random_state=40)
print(X.shape, y.shape)
# Out:
# (500, 5) (500,)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
df = pd.DataFrame(X_pca, columns = ['PCA1', 'PCA2'])
df['label'] = y

# %%
sns.scatterplot(x=df['PCA1'], y=df['PCA2'], hue=df['label'], palette= 'Set2')
# Out:
# <Axes: xlabel='PCA1', ylabel='PCA2'>
